# %%
import os
import pandas as pd
import datetime
from sklearn.model_selection import StratifiedShuffleSplit

DATA_SOURCE = "C:/Users/sbranchett/work/wifi_blog"
ACCESS_POINT = os.path.join(DATA_SOURCE, "strat_train_set.csv")

train_data = pd.read_csv(ACCESS_POINT, delimiter=",")

print(train_data)
# Out:
#        Unnamed: 0  clientCount      bucket_datetime bucket_date bucket_time  \
# 0           11688           15  2021-05-15 15:05:00  2021-05-15    15:05:00
# 1           61351            1  2021-05-20 04:00:00  2021-05-20    04:00:00
# 2           55780          101  2021-05-19 15:45:00  2021-05-19    15:45:00
# 3           26158           12  2021-05-16 22:50:00  2021-05-16    22:50:00
# 4           34879           16  2021-05-17 17:55:00  2021-05-17    17:55:00
# ...           ...          ...                  ...         ...         ...
# 62527       50892            4  2021-05-19 05:05:00  2021-05-19    05:05:00
# 62528       33498          247  2021-05-17 14:55:00  2021-05-17    14:55:00
# 62529        4160            2  2021-05-14 22:35:00  2021-05-14    22:35:00
# 62530       56082            8  2021-05-19 16:25:00  2021-05-19    16:25:00
# 62531       55786          670  2021-05-19 15:50:00  2021-05-19    15:50:00
#
#                                 building  weekday  uni_hols academic_yr
# 0                        37-Sportcentrum    False     False       Learn
# 1                             36-ESP-Lab     True     False    Exam_BSc
# 2                          66-Fellowship     True     False    Exam_BSc
# 3                              32-OCP-IO    False     False       Learn
# 4                                 64-HSL     True     False    Exam_BSc
# ...                                  ...      ...       ...         ...
# 62527                            28- WNI     True     False    Exam_BSc
# 62528  36-EWI LB_K t/m 3 & HB_K  t/m 2e      True     False    Exam_BSc
# 62529                      35-Drebbelweg     True     False       Learn
# 62530                          63-Simona     True     False    Exam_BSc
# 62531                         08-BK-City     True     False    Exam_BSc
#
# [62532 rows x 9 columns]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

train_data.hist(bins=50, figsize=(10,5))
plt.show()

# %%
print(train_data["building"].value_counts())
# Out:
# 03-Science Center                    1646
# 36-ESP-Lab                           1646
# 30-IKC_ISD-FMVG                      1646
# 31-TBM                               1646
# 46-P E lab                           1646
# 32a- Learninglab                     1646
# 33-Pulse                             1646
# 20-Aula                              1646
# 61-Vliegtuighal                      1646
# 45-LSL                               1646
# 50-TNW-RID                           1646
# 25-GreenVillage                      1646
# None                                 1646
# 34-3ME                               1646
# 26-Bouwcampus                        1646
# 05-TNW-BIO                           1646
# 21-BTUD                              1646
# 63-Simona                            1646
# 64-HSL                               1646
# 43-EGM                               1646
# 30-O S                               1646
# 22-TNW-TN                            1646
# 36-EWI LB_K t/m 3 & HB_K  t/m 2e     1645
# 62-LR                                1645
# 37-Sportcentrum                      1645
# 19-Studuitzendbureau                 1645
# 58-TNW-Zuid                          1645
# 66-Fellowship                        1645
# 08-BK-City                           1645
# 23-CITG                              1645
# 38-Cultureel Centrum                 1645
# 60-LMS                               1645
# Katalyse Labaratorium                1645
# 35-Drebbelweg                        1645
# VLL-LAB(TNO)                         1645
# 32-OCP-IO                            1645
# 28- WNI                              1645
# 36-EWI-HB                            1645
# Name: building, dtype: int64

# %% [markdown]
# # Want a graph of clientCount vs bucket_datetime per building

# %%
aula = train_data[["bucket_datetime", "clientCount", "building"]].copy()
aula = aula.loc[aula["building"] == "20-Aula"]
print(aula)
# Out:
#            bucket_datetime  clientCount building
# 27     2021-05-18 10:10:00           29  20-Aula
# 57     2021-05-16 02:30:00            4  20-Aula
# 82     2021-05-16 17:15:00           25  20-Aula
# 145    2021-05-16 03:25:00            4  20-Aula
# 150    2021-05-21 05:05:00            4  20-Aula
# ...                    ...          ...      ...
# 62295  2021-05-18 06:35:00            8  20-Aula
# 62342  2021-05-20 09:00:00           27  20-Aula
# 62355  2021-05-18 23:50:00            7  20-Aula
# 62436  2021-05-16 08:10:00            4  20-Aula
# 62442  2021-05-17 12:10:00           74  20-Aula
#
# [1646 rows x 3 columns]

# %%
plt.figure(figsize=(20, 12))
plt.scatter(aula["bucket_datetime"], aula["clientCount"])
plt.savefig('aula.png')
plt.show()
